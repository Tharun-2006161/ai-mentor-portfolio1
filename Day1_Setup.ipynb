# %% [markdown]
# <a href="https://colab.research.google.com/github/Tharun-2006161/ai-mentor-portfolio1/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass

os.environ['GEMINI_API_KEY'] = getpass.getpass(
    'Paste your Google AI Studio key: '
)
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai

client = genai.Client(
    api_key=os.environ['GEMINI_API_KEY']
)

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)

print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the progression of skills needed for successful AI implementation:
#
# *   **Foundational Technical Skills:** Starts with data management and machine learning engineering to build, train, and evaluate core AI models.
# *   **Application Development:** Focuses on integrating these AI models into practical, user-facing applications and systems.
# *   **Domain Expertise & Ethics:** Emphasizes understanding the specific industry context and ensuring AI solutions are responsible, ethical, and relevant to business needs.
# *   **Strategic Leadership:** The apex involves defining AI vision, resource allocation, managing projects, and communicating AI's value and impact across an organization.
